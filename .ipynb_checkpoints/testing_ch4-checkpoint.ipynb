# %% [markdown]
# # Chapter 4 - Testing

# %% [markdown]
# First import the required modules (with abbreviated names).

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from util_fig import myfigure        # plotting routine from Steven

# %%
# Define the solution function, u(x,t;lam).
def uxt(x,t,lam):
    X = np.array(3*np.sin(np.pi*x) + np.sin(3*np.pi*x))
    T = np.array(np.exp(-lam * math.pow(np.pi,2) * t))
    return np.outer(T, X)

# %%
# Data components (in dictionary).


# Time. 
ip_data = {
    'T': 0.05,  # final time
    'nt': 3     # number of temporal measurements
}
ip_data['t_obs'] = ip_data['T']*np.arange(1,ip_data['nt']+1)/ip_data['nt']   # measurement times


# Space
ip_data['nx'] = 4                                                   # number of spatial measurements
ip_data['x_obs'] = np.arange(1,ip_data['nx']+1)/(1+ip_data['nx'])   # observation locations


# Spatial locations (plotting).
x = np.linspace(0,1,50)


# True observations.
ip_data['lam'] = 5*np.pi/3                                                     # thermal conductivity
ip_data['G'] = uxt(ip_data['x_obs'],ip_data['t_obs'],ip_data['lam']).ravel()   # true obs
ip_data['nd'] = ip_data['nx']*ip_data['nt']                                    # number of obs


# Noise.
ip_data['seed'] = 0                                                           # seed RNG
np.random.seed(0)
ip_data['noise_ratio'] = 5/100                                                    # 5% signal-noise ratio
ip_data['sig_rho'] = np.sqrt(ip_data['noise_ratio'] * np.mean(ip_data['G']))      # noise std
ip_data['rho_noise'] = np.random.normal(0,ip_data['sig_rho'],(ip_data['nd'],1)).ravel()   # noise value


# Noisy data.
ip_data['d'] = ip_data['G'] + ip_data['rho_noise']


# Print dictionary to screen.
for key in ip_data:
    print(key, ip_data[key])
# Out:
# T 0.05
# nt 3
# t_obs [0.01666667 0.03333333 0.05      ]
# nx 4
# x_obs [0.2 0.4 0.6 0.8]
# lam 5.235987755982989
# G [1.14716077 0.95739325 0.95739325 1.14716077 0.48481133 0.40461207
#  0.40461207 0.48481133 0.20489022 0.17099654 0.17099654 0.20489022]
# nd 12
# seed 0
# noise_ratio 0.05
# sig_rho 0.16757744938182473
# rho_noise [ 0.29561539  0.06705732  0.16401441  0.37552317  0.3129606  -0.16376973
#   0.15921339 -0.02536405 -0.01729715  0.06880705  0.02413845  0.24370345]
# d [1.44277616 1.02445058 1.12140767 1.52268394 0.79777194 0.24084234
#  0.56382547 0.45944728 0.18759307 0.23980359 0.19513499 0.44859367]

# %%
# Plot data (seperate commands)


# Matrix representation of noisy data.
d_mat = np.reshape(ip_data["d"],(ip_data["nt"],ip_data["nx"]))


# Subplot routine.
fig, (ax1, ax2, ax3, ax4) = myfigure(nrows=2, ncols=2)

ax1.plot(x, np.squeeze(uxt(x,0,ip_data['lam'])))
ax1.set_xlabel('x')
ax1.set_ylabel('u(x,0)')    
ax1.axis([0, 1, 0, 3])

ax2.plot(x, np.squeeze(uxt(x,ip_data['t_obs'][0],ip_data['lam'])))
ax2.plot(ip_data['x_obs'], d_mat[0,:], 'xr')
ax2.set_xlabel('x')
ax2.set_ylabel('u(x,T/3)')    
ax2.axis([0, 1, 0, 3])

ax3.plot(x, np.squeeze(uxt(x,ip_data['t_obs'][1],ip_data['lam'])))
ax3.plot(ip_data['x_obs'], d_mat[1,:], 'xr')
ax3.set_xlabel('x')
ax3.set_ylabel('u(x,2T/3)')    
ax3.axis([0, 1, 0, 3])

ax4.plot(x, np.squeeze(uxt(x,ip_data['t_obs'][2],ip_data['lam'])))
ax4.plot(ip_data['x_obs'], d_mat[2,:], 'xr')
ax4.set_xlabel('x')
ax4.set_ylabel('u(x,T)')    
ax4.axis([0, 1, 0, 3])
# Out:
# [0, 1, 0, 3]

# %%
# Labels for y-axes.
ylabs = ['u(x,0)', 'u(x,T/3)','u(x,2T/3)','u(x,T)']

# Subplot routine from Steven.
fig, ax = myfigure(nrows=2, ncols=2)


for i,axi in enumerate(ax):
    
    if i == 0:
        # Initial data.
        axi.plot(x, np.squeeze(uxt(x,0,ip_data['lam'])))
    else:
        # Measurement times data.
        axi.plot(x, np.squeeze(uxt(x,ip_data['t_obs'][i-1],ip_data['lam'])))
        axi.plot(ip_data['x_obs'], d_mat[i-1,:], 'xr')
        
    axi.set_xlabel('x')
    axi.set_ylabel(ylabs[i])    
    axi.axis([0, 1, 0, 3])

plt.savefig('test.pdf', dpi=300)

# %%
# Function to convert (mu,sigma) [Normal] to (m,s) [logNorm].
# Y = exp(X): X~N(m,s^2); Y~logN(mu,sigma^2)

def m_s_from_mu_sig(mu,sig):

    c = 1 + np.power(sig/mu,2) # constant
    
    m = np.log(mu/np.sqrt(c))
    s = np.sqrt(np.log(c))
    
    return m,s

# %%
from scipy.stats import uniform as Unif
from scipy.stats import norm as Norm
from scipy.stats import multivariate_normal as mvNorm


# Posterior
def posterior(theta, prior, ip_data):
    
    # Prior density.
    if prior[0] == "unif":
        p0 = Unif.pdf(theta, prior[1], prior[2]-prior[1])  # Uniform pdf
    elif prior[0] == "normal":
        p0 = Norm.pdf(theta, prior[1], prior[2]) # Gaussian pdf

    
    # Forward evaluation.
    F = uxt(ip_data['x_obs'], ip_data['t_obs'], np.exp(theta)).ravel()
    
    
    # Evaluate likelihood (multivariate Normal).
    L = mvNorm.pdf(F, ip_data['d'], ip_data['sig_rho'])

    
    # Return evaluation of the posterior., prior and likelihood.
    return p0*L, p0, L

# %%
# Test the posterior by plotting it.

Nt = 5000   # number of evaluation points

tv = np.linspace(0,3, Nt) # theta values
p0 = np.zeros(Nt)     # prior evaluations
Lv = np.zeros(Nt)     # likelihood evaluations


# Prior parameters
m, s = m_s_from_mu_sig(4,1)
prior = ["normal", m, s]


for n in range(Nt):
    dummy_var, p0[n], Lv[n] = posterior(tv[n], prior, ip_data)
    
    
# Posterior evaluations
pv = p0*Lv


# Normalise.
p0 = p0/np.trapz(p0,tv)
Lv = Lv/np.trapz(Lv,tv)
pv = pv/np.trapz(pv,tv)


# Plot.
fig, ax = myfigure()

ax.plot(tv, pv, label='posterior')
ax.plot(tv, Lv, label='likelihood')
ax.plot(tv, p0, label='prior')
ax.set_xlabel('theta')
ax.set_ylabel('probability density')    
leg = ax.legend();

# %%
# MCMC Routine

NB = int(1e2)  # no. burn in samples
N = int(1e2)   # no samples

nbins = 100  # number of histogram bins

sig_q = 5.5e-1  # proposal standard deviation



# MCMC Sampling.
tvec = np.zeros(N+NB)  # storage for samples values of theta
count = 0 # counter for number of accepted samples

# Initial state
tvec[0] = np.log(ip_data['lam'])  # true value


# Evaluate posterior at true state.
post, dummy1, dummy2 = posterior(tvec[0],prior,ip_data)


# Monte Carlo loop
for n in range(NB+N-1):
    
    t_p = Norm.rvs(tvec[n],sig_q)  # proposal value
    
    post_p, dummy1, dummy2 = posterior(t_p, prior, ip_data) # evaluate posterior at proposal

    alpha = min(1, post_p/post)  # acceptance probability
    
    z = Unif.rvs()
    
    if z < alpha:
        # accept
        tvec[n+1] = t_p
        post = post_p
        
        if n > NB:
            count = count + 1
            
    else:
        # reject
        tvec[n+1] = tvec[n]
    
    
    # Output progress updates to screen.
    if n < NB-2:
        if round(100*(n+2)/NB) > round(100*(n+1)/NB):
            print("Burning in, progress: " + str(n+2) + "/" + str(NB) + " samples computed, " + str(round(100*(n+2)/NB)) + "% complete.")
    elif n == NB-2:
        print("Burn in complete.")
           
    elif n > NB-2:
        if round(100*(n-NB+2)/N) > round(100*(n-NB+1)/N):
            print(n-NB+2)
            print("Progress: " + str(n-NB+2) + "/" + str(N) + " samples computed, " + str(round(100*(n-NB+2)/N)) + "% complete.")    

# Proportion of proposals accepted.            
prop = count/N
print("Proportion of proposals accepted is " + str(prop) +  ".")
# Out:
# Burning in, progress: 2/100 samples computed, 2% complete.
# Burning in, progress: 3/100 samples computed, 3% complete.
# Burning in, progress: 4/100 samples computed, 4% complete.
# Burning in, progress: 5/100 samples computed, 5% complete.
# Burning in, progress: 6/100 samples computed, 6% complete.
# Burning in, progress: 7/100 samples computed, 7% complete.
# Burning in, progress: 8/100 samples computed, 8% complete.
# Burning in, progress: 9/100 samples computed, 9% complete.
# Burning in, progress: 10/100 samples computed, 10% complete.
# Burning in, progress: 11/100 samples computed, 11% complete.
# Burning in, progress: 12/100 samples computed, 12% complete.
# Burning in, progress: 13/100 samples computed, 13% complete.
# Burning in, progress: 14/100 samples computed, 14% complete.
# Burning in, progress: 15/100 samples computed, 15% complete.
# Burning in, progress: 16/100 samples computed, 16% complete.
# Burning in, progress: 17/100 samples computed, 17% complete.
# Burning in, progress: 18/100 samples computed, 18% complete.
# Burning in, progress: 19/100 samples computed, 19% complete.
# Burning in, progress: 20/100 samples computed, 20% complete.
# Burning in, progress: 21/100 samples computed, 21% complete.
# Burning in, progress: 22/100 samples computed, 22% complete.
# Burning in, progress: 23/100 samples computed, 23% complete.
# Burning in, progress: 24/100 samples computed, 24% complete.
# Burning in, progress: 25/100 samples computed, 25% complete.
# Burning in, progress: 26/100 samples computed, 26% complete.
# Burning in, progress: 27/100 samples computed, 27% complete.
# Burning in, progress: 28/100 samples computed, 28% complete.
# Burning in, progress: 29/100 samples computed, 29% complete.
# Burning in, progress: 30/100 samples computed, 30% complete.
# Burning in, progress: 31/100 samples computed, 31% complete.
# Burning in, progress: 32/100 samples computed, 32% complete.
# Burning in, progress: 33/100 samples computed, 33% complete.
# Burning in, progress: 34/100 samples computed, 34% complete.
# Burning in, progress: 35/100 samples computed, 35% complete.
# Burning in, progress: 36/100 samples computed, 36% complete.
# Burning in, progress: 37/100 samples computed, 37% complete.
# Burning in, progress: 38/100 samples computed, 38% complete.
# Burning in, progress: 39/100 samples computed, 39% complete.
# Burning in, progress: 40/100 samples computed, 40% complete.
# Burning in, progress: 41/100 samples computed, 41% complete.
# Burning in, progress: 42/100 samples computed, 42% complete.
# Burning in, progress: 43/100 samples computed, 43% complete.
# Burning in, progress: 44/100 samples computed, 44% complete.
# Burning in, progress: 45/100 samples computed, 45% complete.
# Burning in, progress: 46/100 samples computed, 46% complete.
# Burning in, progress: 47/100 samples computed, 47% complete.
# Burning in, progress: 48/100 samples computed, 48% complete.
# Burning in, progress: 49/100 samples computed, 49% complete.
# Burning in, progress: 50/100 samples computed, 50% complete.
# Burning in, progress: 51/100 samples computed, 51% complete.
# Burning in, progress: 52/100 samples computed, 52% complete.
# Burning in, progress: 53/100 samples computed, 53% complete.
# Burning in, progress: 54/100 samples computed, 54% complete.
# Burning in, progress: 55/100 samples computed, 55% complete.
# Burning in, progress: 56/100 samples computed, 56% complete.
# Burning in, progress: 57/100 samples computed, 57% complete.
# Burning in, progress: 58/100 samples computed, 58% complete.
# Burning in, progress: 59/100 samples computed, 59% complete.
# Burning in, progress: 60/100 samples computed, 60% complete.
# Burning in, progress: 61/100 samples computed, 61% complete.
# Burning in, progress: 62/100 samples computed, 62% complete.
# Burning in, progress: 63/100 samples computed, 63% complete.
# Burning in, progress: 64/100 samples computed, 64% complete.
# Burning in, progress: 65/100 samples computed, 65% complete.
# Burning in, progress: 66/100 samples computed, 66% complete.
# Burning in, progress: 67/100 samples computed, 67% complete.
# Burning in, progress: 68/100 samples computed, 68% complete.
# Burning in, progress: 69/100 samples computed, 69% complete.
# Burning in, progress: 70/100 samples computed, 70% complete.
# Burning in, progress: 71/100 samples computed, 71% complete.
# Burning in, progress: 72/100 samples computed, 72% complete.
# Burning in, progress: 73/100 samples computed, 73% complete.
# Burning in, progress: 74/100 samples computed, 74% complete.
# Burning in, progress: 75/100 samples computed, 75% complete.
# Burning in, progress: 76/100 samples computed, 76% complete.
# Burning in, progress: 77/100 samples computed, 77% complete.
# Burning in, progress: 78/100 samples computed, 78% complete.
# Burning in, progress: 79/100 samples computed, 79% complete.
# Burning in, progress: 80/100 samples computed, 80% complete.
# Burning in, progress: 81/100 samples computed, 81% complete.
# Burning in, progress: 82/100 samples computed, 82% complete.
# Burning in, progress: 83/100 samples computed, 83% complete.
# Burning in, progress: 84/100 samples computed, 84% complete.
# Burning in, progress: 85/100 samples computed, 85% complete.
# Burning in, progress: 86/100 samples computed, 86% complete.
# Burning in, progress: 87/100 samples computed, 87% complete.
# Burning in, progress: 88/100 samples computed, 88% complete.
# Burning in, progress: 89/100 samples computed, 89% complete.
# Burning in, progress: 90/100 samples computed, 90% complete.
# Burning in, progress: 91/100 samples computed, 91% complete.
# Burning in, progress: 92/100 samples computed, 92% complete.
# Burning in, progress: 93/100 samples computed, 93% complete.
# Burning in, progress: 94/100 samples computed, 94% complete.
# Burning in, progress: 95/100 samples computed, 95% complete.
# Burning in, progress: 96/100 samples computed, 96% complete.
# Burning in, progress: 97/100 samples computed, 97% complete.
# Burning in, progress: 98/100 samples computed, 98% complete.
# Burning in, progress: 99/100 samples computed, 99% complete.
# Burn in complete.
# 1
# Progress: 1/100 samples computed, 1% complete.
# 2
# Progress: 2/100 samples computed, 2% complete.
# 3
# Progress: 3/100 samples computed, 3% complete.
# 4
# Progress: 4/100 samples computed, 4% complete.
# 5
# Progress: 5/100 samples computed, 5% complete.
# 6
# Progress: 6/100 samples computed, 6% complete.
# 7
# Progress: 7/100 samples computed, 7% complete.
# 8
# Progress: 8/100 samples computed, 8% complete.
# 9
# Progress: 9/100 samples computed, 9% complete.
# 10
# Progress: 10/100 samples computed, 10% complete.
# 11
# Progress: 11/100 samples computed, 11% complete.
# 12
# Progress: 12/100 samples computed, 12% complete.
# 13
# Progress: 13/100 samples computed, 13% complete.
# 14
# Progress: 14/100 samples computed, 14% complete.
# 15
# Progress: 15/100 samples computed, 15% complete.
# 16
# Progress: 16/100 samples computed, 16% complete.
# 17
# Progress: 17/100 samples computed, 17% complete.
# 18
# Progress: 18/100 samples computed, 18% complete.
# 19
# Progress: 19/100 samples computed, 19% complete.
# 20
# Progress: 20/100 samples computed, 20% complete.
# 21
# Progress: 21/100 samples computed, 21% complete.
# 22
# Progress: 22/100 samples computed, 22% complete.
# 23
# Progress: 23/100 samples computed, 23% complete.
# 24
# Progress: 24/100 samples computed, 24% complete.
# 25
# Progress: 25/100 samples computed, 25% complete.
# 26
# Progress: 26/100 samples computed, 26% complete.
# 27
# Progress: 27/100 samples computed, 27% complete.
# 28
# Progress: 28/100 samples computed, 28% complete.
# 29
# Progress: 29/100 samples computed, 29% complete.
# 30
# Progress: 30/100 samples computed, 30% complete.
# 31
# Progress: 31/100 samples computed, 31% complete.
# 32
# Progress: 32/100 samples computed, 32% complete.
# 33
# Progress: 33/100 samples computed, 33% complete.
# 34
# Progress: 34/100 samples computed, 34% complete.
# 35
# Progress: 35/100 samples computed, 35% complete.
# 36
# Progress: 36/100 samples computed, 36% complete.
# 37
# Progress: 37/100 samples computed, 37% complete.
# 38
# Progress: 38/100 samples computed, 38% complete.
# 39
# Progress: 39/100 samples computed, 39% complete.
# 40
# Progress: 40/100 samples computed, 40% complete.
# 41
# Progress: 41/100 samples computed, 41% complete.
# 42
# Progress: 42/100 samples computed, 42% complete.
# 43
# Progress: 43/100 samples computed, 43% complete.
# 44
# Progress: 44/100 samples computed, 44% complete.
# 45
# Progress: 45/100 samples computed, 45% complete.
# 46
# Progress: 46/100 samples computed, 46% complete.
# 47
# Progress: 47/100 samples computed, 47% complete.
# 48
# Progress: 48/100 samples computed, 48% complete.
# 49
# Progress: 49/100 samples computed, 49% complete.
# 50
# Progress: 50/100 samples computed, 50% complete.
# 51
# Progress: 51/100 samples computed, 51% complete.
# 52
# Progress: 52/100 samples computed, 52% complete.
# 53
# Progress: 53/100 samples computed, 53% complete.
# 54
# Progress: 54/100 samples computed, 54% complete.
# 55
# Progress: 55/100 samples computed, 55% complete.
# 56
# Progress: 56/100 samples computed, 56% complete.
# 57
# Progress: 57/100 samples computed, 57% complete.
# 58
# Progress: 58/100 samples computed, 58% complete.
# 59
# Progress: 59/100 samples computed, 59% complete.
# 60
# Progress: 60/100 samples computed, 60% complete.
# 61
# Progress: 61/100 samples computed, 61% complete.
# 62
# Progress: 62/100 samples computed, 62% complete.
# 63
# Progress: 63/100 samples computed, 63% complete.
# 64
# Progress: 64/100 samples computed, 64% complete.
# 65
# Progress: 65/100 samples computed, 65% complete.
# 66
# Progress: 66/100 samples computed, 66% complete.
# 67
# Progress: 67/100 samples computed, 67% complete.
# 68
# Progress: 68/100 samples computed, 68% complete.
# 69
# Progress: 69/100 samples computed, 69% complete.
# 70
# Progress: 70/100 samples computed, 70% complete.
# 71
# Progress: 71/100 samples computed, 71% complete.
# 72
# Progress: 72/100 samples computed, 72% complete.
# 73
# Progress: 73/100 samples computed, 73% complete.
# 74
# Progress: 74/100 samples computed, 74% complete.
# 75
# Progress: 75/100 samples computed, 75% complete.
# 76
# Progress: 76/100 samples computed, 76% complete.
# 77
# Progress: 77/100 samples computed, 77% complete.
# 78
# Progress: 78/100 samples computed, 78% complete.
# 79
# Progress: 79/100 samples computed, 79% complete.
# 80
# Progress: 80/100 samples computed, 80% complete.
# 81
# Progress: 81/100 samples computed, 81% complete.
# 82
# Progress: 82/100 samples computed, 82% complete.
# 83
# Progress: 83/100 samples computed, 83% complete.
# 84
# Progress: 84/100 samples computed, 84% complete.
# 85
# Progress: 85/100 samples computed, 85% complete.
# 86
# Progress: 86/100 samples computed, 86% complete.
# 87
# Progress: 87/100 samples computed, 87% complete.
# 88
# Progress: 88/100 samples computed, 88% complete.
# 89
# Progress: 89/100 samples computed, 89% complete.
# 90
# Progress: 90/100 samples computed, 90% complete.
# 91
# Progress: 91/100 samples computed, 91% complete.
# 92
# Progress: 92/100 samples computed, 92% complete.
# 93
# Progress: 93/100 samples computed, 93% complete.
# 94
# Progress: 94/100 samples computed, 94% complete.
# 95
# Progress: 95/100 samples computed, 95% complete.
# 96
# Progress: 96/100 samples computed, 96% complete.
# 97
# Progress: 97/100 samples computed, 97% complete.
# 98
# Progress: 98/100 samples computed, 98% complete.
# 99
# Progress: 99/100 samples computed, 99% complete.
# 100
# Progress: 100/100 samples computed, 100% complete.
# Proportion of proposals accepted is 0.29.

# %%
xbv = [1,2,3,4,5,6]
print(xbv)

print(xbv[-2:])
# Out:
# [1, 2, 3, 4, 5, 6]
# [5, 6]

# %%
chain = tvec[NB:]
print(len(chain))
print(chain[96:102])
# Out:
# 100
# [1.36281988 1.36281988 1.36281988 1.36281988]

# %%
print(prop)

print(tvec[NB:NB+20])

chain = tvec[NB:]

print(len(chain))
len(range(1,N+1))


# Plot
fig, ax = myfigure()

ax.plot(range(1,N+1), chain, label='path')
ax.set_xlabel('iterate, n')
ax.set_ylabel('theta')    
leg = ax.legend();
# Out:
# 0.27
# [1.49840409 1.49840409 1.49840409 1.38764259 1.38764259 1.38963155
#  1.38963155 1.38963155 1.38963155 1.38963155 1.38963155 1.38963155
#  1.38963155 1.38963155 1.38963155 1.38963155 1.38963155 1.38963155
#  1.51955557 1.51955557]
# 200

# %%
# Histogram results


# 
hist, bin_edges = np.histogram(chain, 100, density=1)

bin_centres = (bin_edges[1:] + bin_edges[:-1])/2

#print(bin_edges)
#print(bin_centres)

# Plot histogram (inbuilt function)
plt.hist(chain, bins=100, density=1)


# Plot histogram manually.
fig, ax = myfigure()

ax.plot(bin_centres, hist, label='posterior')
ax.set_xlabel('theta')
ax.set_ylabel('probability density')    
leg = ax.legend();

# %%
for i in range(1,4):
    print(i)
# Out:
# 1
# 2
# 3

# %%
x = [1,2,3,4,5,6]
print(x[1:])

print(np.arange(1,4))

y = x[3:]
print(y)

print(2/1)
# Out:
# [2, 3, 4, 5, 6]
# [1 2 3]
# [4, 5, 6]
# 2.0
